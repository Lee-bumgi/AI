# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

train = pd.read_csv('./data/train.csv', index_col='no')
test = pd.read_csv('./data/test.csv', index_col='no')

def strip_title(row):
    return row.strip()

# train 공백제거
# except pass 는 수치형나오면 오류나는거를 pass한것
for i in range(len(train.columns)):
    try:
        train.iloc[:,i] = train.iloc[:,i].apply(strip_title)
    except:
        pass
# test 공백제거
for i in range(len(test.columns)):
    try:
        test.iloc[:,i] = test.iloc[:,i].apply(strip_title)
    except:
        pass


# ?을 other로 변환
train['occupation'] = train['occupation'].replace('?','other')
train['workclass'] = train['workclass'].replace('?','other')
train['native-country'] = train['native-country'].replace('?','other')

# ?을 other로 변환
test['occupation'] = test['occupation'].replace('?','other')
test['workclass'] = test['workclass'].replace('?','other')
test['native-country'] = test['native-country'].replace('?','other')

# train.drop(['fnlwgt','capital-gain', 'capital-loss','education'],axis=1,inplace=True)
# test.drop(['fnlwgt','capital-gain', 'capital-loss','education'],axis=1,inplace=True)

train.drop(['fnlwgt','education'],axis=1,inplace=True)
test.drop(['fnlwgt','education'],axis=1,inplace=True)

train['native-country'] = train['native-country'].map({'United-States':'United-States',"other":'United-States'})
train['native-country'].fillna("other-country",inplace=True)
test['native-country'] = test['native-country'].map({'United-States':'United-States',"other":'United-States'})
test['native-country'].fillna("other-country",inplace=True)

# 인코딩할 컬럼명만 선택
categorical_features = ['workclass', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# categorical_features = ['workclass','occupation']
# 반복문으로 인코딩하기
for feature_name in categorical_features:
    one_hot = pd.get_dummies(train[feature_name], prefix = feature_name)
    train = pd.concat([train,one_hot], axis=1) # 기존 데이터 끝에 one_hot을 붙임.
    train.drop(feature_name, axis=1, inplace=True) # 기존 글자컬럼을 삭제
    
for feature_name in categorical_features:
    one_hot = pd.get_dummies(test[feature_name], prefix = feature_name)
    test = pd.concat([test,one_hot], axis=1) # 기존 데이터 끝에 one_hot을 붙임.
    test.drop(feature_name, axis=1, inplace=True) # 기존 글자컬럼을 삭제
#train.drop("workclass_other", axis = 1, inplace = True)
#test.drop("workclass_other", axis = 1, inplace = True)


train.sort_index(axis=1, inplace=True)
test.sort_index(axis=1, inplace=True)
X_train = train.drop(['income'], axis=1)
y_train = train.income
X_test=test
X_train.sort_index(axis=1, inplace=True)
X_test.sort_index(axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, random_state=0)

# %%
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=0 )

# %%
from hyperopt import hp

# max_depth는 5에서 20까지 1간격으로, min_child_weight는 1에서 2까지 1간격으로
# colsample_bytree는 0.5에서 1사이, learning_rate는 0.01에서 0.2 사이 정규 분포된 값으로 검색.
xgb_search_space = {'max_depth': hp.quniform('max_depth', 6, 12, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.4, 1),
                   }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

# fmin()에서 입력된 search_space 값으로 입력된 모든 값은 실수형임.
# XGBClassifier의 정수형 하이퍼 파라미터는 정수형 변환을 해줘야 함.
# 정확도는 높을수록 더 좋은 수치임. -1 * 정확도를 곱해서 큰 정확도 값일수록 최소가 되도록 변환
def objective_func(search_space):
    # 수행 시간 절약을 위해 nestimators는 100으로 축소
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=5)
    
    # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=100, # 최대 반복 횟수를 지정합니다.
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|█████████████████████████████████████████████| 100/100 [03:55<00:00,  2.36s/trial, best loss: -0.8717353038909093]
# best: {'colsample_bytree': 0.49078457271407105, 'learning_rate': 0.09313005317333836, 'max_depth': 9.0, 'min_child_weight': 2.0}

# %%
print('colsample_bytree:{0}, learning_rate:{1}, max_depth:{2}, min_child_weight:{3}'.format(
    round(best['colsample_bytree'], 5), round(best['learning_rate'], 5),
    int(best['max_depth']), int(best['min_child_weight'])))
# Out:
# colsample_bytree:0.49078, learning_rate:0.09313, max_depth:9, min_child_weight:2

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.5f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5)
                           )

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric='logloss',
                eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.64455	validation_1-logloss:0.64427
# [1]	validation_0-logloss:0.60497	validation_1-logloss:0.60440
# [2]	validation_0-logloss:0.56985	validation_1-logloss:0.56910
# [3]	validation_0-logloss:0.54150	validation_1-logloss:0.54046
# [4]	validation_0-logloss:0.52040	validation_1-logloss:0.51900
# [5]	validation_0-logloss:0.49672	validation_1-logloss:0.49616
# [6]	validation_0-logloss:0.48043	validation_1-logloss:0.47977
# [7]	validation_0-logloss:0.46482	validation_1-logloss:0.46434
# [8]	validation_0-logloss:0.45190	validation_1-logloss:0.45140
# [9]	validation_0-logloss:0.43842	validation_1-logloss:0.43858
# [10]	validation_0-logloss:0.42202	validation_1-logloss:0.42178
# [11]	validation_0-logloss:0.41113	validation_1-logloss:0.41056
# [12]	validation_0-logloss:0.39629	validation_1-logloss:0.39560
# [13]	validation_0-logloss:0.38854	validation_1-logloss:0.38827
# [14]	validation_0-logloss:0.37720	validation_1-logloss:0.37684
# [15]	validation_0-logloss:0.36871	validation_1-logloss:0.36901
# [16]	validation_0-logloss:0.36082	validation_1-logloss:0.36228
# [17]	validation_0-logloss:0.35180	validation_1-logloss:0.35351
# [18]	validation_0-logloss:0.34755	validation_1-logloss:0.34930
# [19]	validation_0-logloss:0.34239	validation_1-logloss:0.34484
# [20]	validation_0-logloss:0.33601	validation_1-logloss:0.33873
# [21]	validation_0-logloss:0.33208	validation_1-logloss:0.33530
# [22]	validation_0-logloss:0.32573	validation_1-logloss:0.32943
# [23]	validation_0-logloss:0.32208	validation_1-logloss:0.32609
# [24]	validation_0-logloss:0.31876	validation_1-logloss:0.32377
# C:\Users\bumgi\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\bumgi\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [25]	validation_0-logloss:0.31528	validation_1-logloss:0.32104
# [26]	validation_0-logloss:0.31022	validation_1-logloss:0.31630
# [27]	validation_0-logloss:0.30607	validation_1-logloss:0.31216
# [28]	validation_0-logloss:0.30331	validation_1-logloss:0.31009
# [29]	validation_0-logloss:0.29922	validation_1-logloss:0.30626
# [30]	validation_0-logloss:0.29610	validation_1-logloss:0.30355
# [31]	validation_0-logloss:0.29378	validation_1-logloss:0.30231
# [32]	validation_0-logloss:0.29207	validation_1-logloss:0.30105
# [33]	validation_0-logloss:0.28961	validation_1-logloss:0.29900
# [34]	validation_0-logloss:0.28701	validation_1-logloss:0.29691
# [35]	validation_0-logloss:0.28535	validation_1-logloss:0.29518
# [36]	validation_0-logloss:0.28423	validation_1-logloss:0.29420
# [37]	validation_0-logloss:0.28225	validation_1-logloss:0.29221
# [38]	validation_0-logloss:0.28134	validation_1-logloss:0.29165
# [39]	validation_0-logloss:0.27958	validation_1-logloss:0.29044
# [40]	validation_0-logloss:0.27771	validation_1-logloss:0.28935
# [41]	validation_0-logloss:0.27622	validation_1-logloss:0.28831
# [42]	validation_0-logloss:0.27468	validation_1-logloss:0.28744
# [43]	validation_0-logloss:0.27340	validation_1-logloss:0.28630
# [44]	validation_0-logloss:0.27170	validation_1-logloss:0.28535
# [45]	validation_0-logloss:0.27042	validation_1-logloss:0.28424
# [46]	validation_0-logloss:0.26972	validation_1-logloss:0.28382
# [47]	validation_0-logloss:0.26899	validation_1-logloss:0.28334
# [48]	validation_0-logloss:0.26791	validation_1-logloss:0.28306
# [49]	validation_0-logloss:0.26677	validation_1-logloss:0.28265
# [50]	validation_0-logloss:0.26600	validation_1-logloss:0.28241
# [51]	validation_0-logloss:0.26530	validation_1-logloss:0.28229
# [52]	validation_0-logloss:0.26459	validation_1-logloss:0.28173
# [53]	validation_0-logloss:0.26416	validation_1-logloss:0.28138
# [54]	validation_0-logloss:0.26360	validation_1-logloss:0.28139
# [55]	validation_0-logloss:0.26317	validation_1-logloss:0.28119
# [56]	validation_0-logloss:0.26247	validation_1-logloss:0.28103
# [57]	validation_0-logloss:0.26136	validation_1-logloss:0.28060
# [58]	validation_0-logloss:0.26029	validation_1-logloss:0.27979
# [59]	validation_0-logloss:0.25942	validation_1-logloss:0.27933
# [60]	validation_0-logloss:0.25882	validation_1-logloss:0.27937
# [61]	validation_0-logloss:0.25800	validation_1-logloss:0.27935
# [62]	validation_0-logloss:0.25779	validation_1-logloss:0.27934
# [63]	validation_0-logloss:0.25718	validation_1-logloss:0.27923
# [64]	validation_0-logloss:0.25698	validation_1-logloss:0.27927
# [65]	validation_0-logloss:0.25611	validation_1-logloss:0.27893
# [66]	validation_0-logloss:0.25557	validation_1-logloss:0.27840
# [67]	validation_0-logloss:0.25510	validation_1-logloss:0.27834
# [68]	validation_0-logloss:0.25453	validation_1-logloss:0.27796
# [69]	validation_0-logloss:0.25403	validation_1-logloss:0.27763
# [70]	validation_0-logloss:0.25361	validation_1-logloss:0.27786
# [71]	validation_0-logloss:0.25322	validation_1-logloss:0.27747
# [72]	validation_0-logloss:0.25277	validation_1-logloss:0.27730
# [73]	validation_0-logloss:0.25235	validation_1-logloss:0.27716
# [74]	validation_0-logloss:0.25193	validation_1-logloss:0.27688
# [75]	validation_0-logloss:0.25151	validation_1-logloss:0.27667
# [76]	validation_0-logloss:0.25108	validation_1-logloss:0.27651
# [77]	validation_0-logloss:0.25066	validation_1-logloss:0.27622
# [78]	validation_0-logloss:0.25036	validation_1-logloss:0.27615
# [79]	validation_0-logloss:0.24993	validation_1-logloss:0.27607
# [80]	validation_0-logloss:0.24943	validation_1-logloss:0.27597
# [81]	validation_0-logloss:0.24910	validation_1-logloss:0.27580
# [82]	validation_0-logloss:0.24879	validation_1-logloss:0.27575
# [83]	validation_0-logloss:0.24844	validation_1-logloss:0.27598
# [84]	validation_0-logloss:0.24820	validation_1-logloss:0.27582
# [85]	validation_0-logloss:0.24791	validation_1-logloss:0.27552
# [86]	validation_0-logloss:0.24720	validation_1-logloss:0.27526
# [87]	validation_0-logloss:0.24688	validation_1-logloss:0.27503
# [88]	validation_0-logloss:0.24667	validation_1-logloss:0.27518
# [89]	validation_0-logloss:0.24641	validation_1-logloss:0.27514
# [90]	validation_0-logloss:0.24620	validation_1-logloss:0.27501
# [91]	validation_0-logloss:0.24598	validation_1-logloss:0.27484
# [92]	validation_0-logloss:0.24583	validation_1-logloss:0.27468
# [93]	validation_0-logloss:0.24553	validation_1-logloss:0.27471
# [94]	validation_0-logloss:0.24505	validation_1-logloss:0.27445
# [95]	validation_0-logloss:0.24492	validation_1-logloss:0.27436
# [96]	validation_0-logloss:0.24462	validation_1-logloss:0.27441
# [97]	validation_0-logloss:0.24420	validation_1-logloss:0.27425
# [98]	validation_0-logloss:0.24402	validation_1-logloss:0.27416
# [99]	validation_0-logloss:0.24381	validation_1-logloss:0.27418
# [100]	validation_0-logloss:0.24351	validation_1-logloss:0.27420
# [101]	validation_0-logloss:0.24334	validation_1-logloss:0.27417
# [102]	validation_0-logloss:0.24305	validation_1-logloss:0.27416
# [103]	validation_0-logloss:0.24296	validation_1-logloss:0.27414
# [104]	validation_0-logloss:0.24280	validation_1-logloss:0.27400
# [105]	validation_0-logloss:0.24214	validation_1-logloss:0.27396
# [106]	validation_0-logloss:0.24200	validation_1-logloss:0.27387
# [107]	validation_0-logloss:0.24188	validation_1-logloss:0.27377
# [108]	validation_0-logloss:0.24173	validation_1-logloss:0.27375
# [109]	validation_0-logloss:0.24164	validation_1-logloss:0.27368
# [110]	validation_0-logloss:0.24143	validation_1-logloss:0.27376
# [111]	validation_0-logloss:0.24122	validation_1-logloss:0.27380
# [112]	validation_0-logloss:0.24112	validation_1-logloss:0.27386
# [113]	validation_0-logloss:0.24083	validation_1-logloss:0.27373
# [114]	validation_0-logloss:0.24069	validation_1-logloss:0.27388
# [115]	validation_0-logloss:0.24040	validation_1-logloss:0.27380
# [116]	validation_0-logloss:0.24022	validation_1-logloss:0.27375
# [117]	validation_0-logloss:0.24007	validation_1-logloss:0.27384
# [118]	validation_0-logloss:0.23986	validation_1-logloss:0.27394
# [119]	validation_0-logloss:0.23970	validation_1-logloss:0.27383
# [120]	validation_0-logloss:0.23953	validation_1-logloss:0.27372
# [121]	validation_0-logloss:0.23942	validation_1-logloss:0.27367
# [122]	validation_0-logloss:0.23927	validation_1-logloss:0.27368
# [123]	validation_0-logloss:0.23917	validation_1-logloss:0.27362
# [124]	validation_0-logloss:0.23900	validation_1-logloss:0.27361
# [125]	validation_0-logloss:0.23890	validation_1-logloss:0.27358
# [126]	validation_0-logloss:0.23883	validation_1-logloss:0.27354
# [127]	validation_0-logloss:0.23867	validation_1-logloss:0.27352
# [128]	validation_0-logloss:0.23833	validation_1-logloss:0.27355
# [129]	validation_0-logloss:0.23822	validation_1-logloss:0.27361
# [130]	validation_0-logloss:0.23804	validation_1-logloss:0.27357
# [131]	validation_0-logloss:0.23786	validation_1-logloss:0.27348
# [132]	validation_0-logloss:0.23767	validation_1-logloss:0.27352
# [133]	validation_0-logloss:0.23759	validation_1-logloss:0.27350
# [134]	validation_0-logloss:0.23748	validation_1-logloss:0.27344
# [135]	validation_0-logloss:0.23707	validation_1-logloss:0.27355
# [136]	validation_0-logloss:0.23691	validation_1-logloss:0.27353
# [137]	validation_0-logloss:0.23683	validation_1-logloss:0.27349
# [138]	validation_0-logloss:0.23671	validation_1-logloss:0.27347
# [139]	validation_0-logloss:0.23651	validation_1-logloss:0.27359
# [140]	validation_0-logloss:0.23636	validation_1-logloss:0.27361
# [141]	validation_0-logloss:0.23626	validation_1-logloss:0.27367
# [142]	validation_0-logloss:0.23568	validation_1-logloss:0.27375
# [143]	validation_0-logloss:0.23548	validation_1-logloss:0.27380
# [144]	validation_0-logloss:0.23533	validation_1-logloss:0.27380
# [145]	validation_0-logloss:0.23528	validation_1-logloss:0.27374
# [146]	validation_0-logloss:0.23524	validation_1-logloss:0.27371
# [147]	validation_0-logloss:0.23474	validation_1-logloss:0.27400
# [148]	validation_0-logloss:0.23422	validation_1-logloss:0.27415
# [149]	validation_0-logloss:0.23409	validation_1-logloss:0.27407
# [150]	validation_0-logloss:0.23390	validation_1-logloss:0.27412
# [151]	validation_0-logloss:0.23368	validation_1-logloss:0.27417
# [152]	validation_0-logloss:0.23336	validation_1-logloss:0.27393
# [153]	validation_0-logloss:0.23322	validation_1-logloss:0.27394
# [154]	validation_0-logloss:0.23312	validation_1-logloss:0.27410
# [155]	validation_0-logloss:0.23285	validation_1-logloss:0.27407
# [156]	validation_0-logloss:0.23280	validation_1-logloss:0.27405
# [157]	validation_0-logloss:0.23256	validation_1-logloss:0.27411
# [158]	validation_0-logloss:0.23251	validation_1-logloss:0.27408
# [159]	validation_0-logloss:0.23247	validation_1-logloss:0.27414
# [160]	validation_0-logloss:0.23244	validation_1-logloss:0.27412
# [161]	validation_0-logloss:0.23240	validation_1-logloss:0.27409
# [162]	validation_0-logloss:0.23237	validation_1-logloss:0.27413
# [163]	validation_0-logloss:0.23225	validation_1-logloss:0.27421
# [164]	validation_0-logloss:0.23219	validation_1-logloss:0.27421
# [165]	validation_0-logloss:0.23211	validation_1-logloss:0.27424
# [166]	validation_0-logloss:0.23208	validation_1-logloss:0.27421
# [167]	validation_0-logloss:0.23206	validation_1-logloss:0.27424
# [168]	validation_0-logloss:0.23202	validation_1-logloss:0.27423
# [169]	validation_0-logloss:0.23171	validation_1-logloss:0.27422
# [170]	validation_0-logloss:0.23167	validation_1-logloss:0.27418
# [171]	validation_0-logloss:0.23165	validation_1-logloss:0.27414
# [172]	validation_0-logloss:0.23151	validation_1-logloss:0.27410
# [173]	validation_0-logloss:0.23103	validation_1-logloss:0.27415
# [174]	validation_0-logloss:0.23080	validation_1-logloss:0.27425
# [175]	validation_0-logloss:0.23076	validation_1-logloss:0.27426
# [176]	validation_0-logloss:0.23065	validation_1-logloss:0.27430
# [177]	validation_0-logloss:0.23063	validation_1-logloss:0.27429
# [178]	validation_0-logloss:0.23033	validation_1-logloss:0.27436
# [179]	validation_0-logloss:0.23013	validation_1-logloss:0.27443
# [180]	validation_0-logloss:0.22973	validation_1-logloss:0.27442
# [181]	validation_0-logloss:0.22969	validation_1-logloss:0.27440
# [182]	validation_0-logloss:0.22966	validation_1-logloss:0.27443
# [183]	validation_0-logloss:0.22940	validation_1-logloss:0.27449
# 오차 행렬
# [[5218  353]
#  [ 583 1173]]
# 정확도: 0.87225, 정밀도: 0.7687, 재현율: 0.6680,    F1: 0.7148, AUC:0.9284
