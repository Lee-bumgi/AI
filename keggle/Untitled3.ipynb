# %%
#데이터처리안한거 3,4 용

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

train = pd.read_csv('./data/train.csv', index_col='no')
test = pd.read_csv('./data/test.csv', index_col='no')

def strip_title(row):
    return row.strip()

# train 공백제거
# except pass 는 수치형나오면 오류나는거를 pass한것
for i in range(len(train.columns)):
    try:
        train.iloc[:,i] = train.iloc[:,i].apply(strip_title)
    except:
        pass
# test 공백제거
for i in range(len(test.columns)):
    try:
        test.iloc[:,i] = test.iloc[:,i].apply(strip_title)
    except:
        pass
    
# ?을 other로 변환
train['occupation'] = train['occupation'].replace('?','other')
train['workclass'] = train['workclass'].replace('?','other')
train['native-country'] = train['native-country'].replace('?','other')

# ?을 other로 변환
test['occupation'] = test['occupation'].replace('?','other')
test['workclass'] = test['workclass'].replace('?','other')
test['native-country'] = test['native-country'].replace('?','other')

# 인코딩할 컬럼명만 선택
categorical_features = ['workclass', 'marital-status', 'occupation', 
                        'education','relationship', 'race', 'sex', 'native-country']
# categorical_features = ['workclass','occupation']
# 반복문으로 인코딩하기
for feature_name in categorical_features:
    one_hot = pd.get_dummies(train[feature_name], prefix = feature_name)
    train = pd.concat([train,one_hot], axis=1) # 기존 데이터 끝에 one_hot을 붙임.
    train.drop(feature_name, axis=1, inplace=True) # 기존 글자컬럼을 삭제
    
for feature_name in categorical_features:
    one_hot = pd.get_dummies(test[feature_name], prefix = feature_name)
    test = pd.concat([test,one_hot], axis=1) # 기존 데이터 끝에 one_hot을 붙임.
    test.drop(feature_name, axis=1, inplace=True) # 기존 글자컬럼을 삭제
train.drop("workclass_other", axis = 1, inplace = True)
test.drop("workclass_other", axis = 1, inplace = True)
train.drop(['fnlwgt'],axis=1,inplace=True)
test.drop(['fnlwgt'],axis=1,inplace=True)

train.sort_index(axis=1, inplace=True)
test.sort_index(axis=1, inplace=True)
X_train = train.drop(['income'], axis=1)
y_train = train.income
X_test=test
X_train.sort_index(axis=1, inplace=True)
X_test.sort_index(axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, random_state=0)
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=0 )

# %%
from hyperopt import hp

# max_depth는 5에서 20까지 1간격으로, min_child_weight는 1에서 2까지 1간격으로
# colsample_bytree는 0.5에서 1사이, learning_rate는 0.01에서 0.2 사이 정규 분포된 값으로 검색.
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 10, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.4, 1),
                   }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

# fmin()에서 입력된 search_space 값으로 입력된 모든 값은 실수형임.
# XGBClassifier의 정수형 하이퍼 파라미터는 정수형 변환을 해줘야 함.
# 정확도는 높을수록 더 좋은 수치임. -1 * 정확도를 곱해서 큰 정확도 값일수록 최소가 되도록 변환
def objective_func(search_space):
    # 수행 시간 절약을 위해 nestimators는 100으로 축소
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=5)
    
    # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials


trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|████████████████████████████████████████████████| 50/50 [02:22<00:00,  2.85s/trial, best loss: -0.872053826987198]
# best: {'colsample_bytree': 0.48089834801608844, 'learning_rate': 0.1816741392195572, 'max_depth': 5.0, 'min_child_weight': 1.0}

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.5f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5)
                           )

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.60271	validation_1-logloss:0.60180
# [1]	validation_0-logloss:0.54522	validation_1-logloss:0.54406
# [2]	validation_0-logloss:0.50179	validation_1-logloss:0.50034
# [3]	validation_0-logloss:0.46423	validation_1-logloss:0.46229
# [4]	validation_0-logloss:0.43406	validation_1-logloss:0.43192
# [5]	validation_0-logloss:0.41298	validation_1-logloss:0.41061
# [6]	validation_0-logloss:0.39784	validation_1-logloss:0.39567
# [7]	validation_0-logloss:0.38163	validation_1-logloss:0.37933
# [8]	validation_0-logloss:0.36664	validation_1-logloss:0.36397
# [9]	validation_0-logloss:0.35718	validation_1-logloss:0.35487
# [10]	validation_0-logloss:0.34894	validation_1-logloss:0.34662
# [11]	validation_0-logloss:0.34276	validation_1-logloss:0.34059
# [12]	validation_0-logloss:0.33658	validation_1-logloss:0.33463
# [13]	validation_0-logloss:0.33112	validation_1-logloss:0.32992
# [14]	validation_0-logloss:0.32422	validation_1-logloss:0.32337
# [15]	validation_0-logloss:0.32039	validation_1-logloss:0.31944
# [16]	validation_0-logloss:0.31672	validation_1-logloss:0.31635
# [17]	validation_0-logloss:0.31362	validation_1-logloss:0.31361
# [18]	validation_0-logloss:0.31145	validation_1-logloss:0.31171
# [19]	validation_0-logloss:0.30740	validation_1-logloss:0.30783
# [20]	validation_0-logloss:0.30523	validation_1-logloss:0.30580
# [21]	validation_0-logloss:0.30373	validation_1-logloss:0.30488
# [22]	validation_0-logloss:0.30259	validation_1-logloss:0.30433
# C:\Users\bumgi\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\bumgi\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [23]	validation_0-logloss:0.29907	validation_1-logloss:0.30107
# [24]	validation_0-logloss:0.29677	validation_1-logloss:0.29900
# [25]	validation_0-logloss:0.29454	validation_1-logloss:0.29718
# [26]	validation_0-logloss:0.29273	validation_1-logloss:0.29554
# [27]	validation_0-logloss:0.29134	validation_1-logloss:0.29435
# [28]	validation_0-logloss:0.29008	validation_1-logloss:0.29386
# [29]	validation_0-logloss:0.28857	validation_1-logloss:0.29258
# [30]	validation_0-logloss:0.28760	validation_1-logloss:0.29175
# [31]	validation_0-logloss:0.28661	validation_1-logloss:0.29129
# [32]	validation_0-logloss:0.28575	validation_1-logloss:0.29063
# [33]	validation_0-logloss:0.28423	validation_1-logloss:0.28938
# [34]	validation_0-logloss:0.28348	validation_1-logloss:0.28891
# [35]	validation_0-logloss:0.28273	validation_1-logloss:0.28843
# [36]	validation_0-logloss:0.28212	validation_1-logloss:0.28801
# [37]	validation_0-logloss:0.28137	validation_1-logloss:0.28769
# [38]	validation_0-logloss:0.28020	validation_1-logloss:0.28703
# [39]	validation_0-logloss:0.27946	validation_1-logloss:0.28647
# [40]	validation_0-logloss:0.27873	validation_1-logloss:0.28590
# [41]	validation_0-logloss:0.27738	validation_1-logloss:0.28474
# [42]	validation_0-logloss:0.27692	validation_1-logloss:0.28484
# [43]	validation_0-logloss:0.27643	validation_1-logloss:0.28441
# [44]	validation_0-logloss:0.27553	validation_1-logloss:0.28380
# [45]	validation_0-logloss:0.27496	validation_1-logloss:0.28344
# [46]	validation_0-logloss:0.27422	validation_1-logloss:0.28292
# [47]	validation_0-logloss:0.27391	validation_1-logloss:0.28269
# [48]	validation_0-logloss:0.27301	validation_1-logloss:0.28194
# [49]	validation_0-logloss:0.27228	validation_1-logloss:0.28131
# [50]	validation_0-logloss:0.27152	validation_1-logloss:0.28083
# [51]	validation_0-logloss:0.27116	validation_1-logloss:0.28085
# [52]	validation_0-logloss:0.27063	validation_1-logloss:0.28081
# [53]	validation_0-logloss:0.26995	validation_1-logloss:0.28020
# [54]	validation_0-logloss:0.26958	validation_1-logloss:0.27986
# [55]	validation_0-logloss:0.26924	validation_1-logloss:0.27955
# [56]	validation_0-logloss:0.26854	validation_1-logloss:0.27939
# [57]	validation_0-logloss:0.26825	validation_1-logloss:0.27933
# [58]	validation_0-logloss:0.26764	validation_1-logloss:0.27887
# [59]	validation_0-logloss:0.26745	validation_1-logloss:0.27883
# [60]	validation_0-logloss:0.26725	validation_1-logloss:0.27867
# [61]	validation_0-logloss:0.26689	validation_1-logloss:0.27850
# [62]	validation_0-logloss:0.26643	validation_1-logloss:0.27820
# [63]	validation_0-logloss:0.26619	validation_1-logloss:0.27806
# [64]	validation_0-logloss:0.26581	validation_1-logloss:0.27801
# [65]	validation_0-logloss:0.26543	validation_1-logloss:0.27793
# [66]	validation_0-logloss:0.26500	validation_1-logloss:0.27765
# [67]	validation_0-logloss:0.26467	validation_1-logloss:0.27774
# [68]	validation_0-logloss:0.26430	validation_1-logloss:0.27751
# [69]	validation_0-logloss:0.26413	validation_1-logloss:0.27760
# [70]	validation_0-logloss:0.26399	validation_1-logloss:0.27756
# [71]	validation_0-logloss:0.26381	validation_1-logloss:0.27751
# [72]	validation_0-logloss:0.26335	validation_1-logloss:0.27741
# [73]	validation_0-logloss:0.26322	validation_1-logloss:0.27733
# [74]	validation_0-logloss:0.26295	validation_1-logloss:0.27747
# [75]	validation_0-logloss:0.26284	validation_1-logloss:0.27737
# [76]	validation_0-logloss:0.26264	validation_1-logloss:0.27722
# [77]	validation_0-logloss:0.26219	validation_1-logloss:0.27706
# [78]	validation_0-logloss:0.26204	validation_1-logloss:0.27702
# [79]	validation_0-logloss:0.26184	validation_1-logloss:0.27707
# [80]	validation_0-logloss:0.26160	validation_1-logloss:0.27709
# [81]	validation_0-logloss:0.26147	validation_1-logloss:0.27706
# [82]	validation_0-logloss:0.26122	validation_1-logloss:0.27703
# [83]	validation_0-logloss:0.26114	validation_1-logloss:0.27704
# [84]	validation_0-logloss:0.26099	validation_1-logloss:0.27699
# [85]	validation_0-logloss:0.26093	validation_1-logloss:0.27688
# [86]	validation_0-logloss:0.26058	validation_1-logloss:0.27656
# [87]	validation_0-logloss:0.26028	validation_1-logloss:0.27659
# [88]	validation_0-logloss:0.25967	validation_1-logloss:0.27673
# [89]	validation_0-logloss:0.25938	validation_1-logloss:0.27642
# [90]	validation_0-logloss:0.25904	validation_1-logloss:0.27655
# [91]	validation_0-logloss:0.25891	validation_1-logloss:0.27663
# [92]	validation_0-logloss:0.25881	validation_1-logloss:0.27651
# [93]	validation_0-logloss:0.25875	validation_1-logloss:0.27645
# [94]	validation_0-logloss:0.25870	validation_1-logloss:0.27639
# [95]	validation_0-logloss:0.25847	validation_1-logloss:0.27631
# [96]	validation_0-logloss:0.25810	validation_1-logloss:0.27622
# [97]	validation_0-logloss:0.25796	validation_1-logloss:0.27609
# [98]	validation_0-logloss:0.25779	validation_1-logloss:0.27615
# [99]	validation_0-logloss:0.25773	validation_1-logloss:0.27612
# [100]	validation_0-logloss:0.25765	validation_1-logloss:0.27605
# [101]	validation_0-logloss:0.25759	validation_1-logloss:0.27598
# [102]	validation_0-logloss:0.25741	validation_1-logloss:0.27585
# [103]	validation_0-logloss:0.25707	validation_1-logloss:0.27578
# [104]	validation_0-logloss:0.25690	validation_1-logloss:0.27584
# [105]	validation_0-logloss:0.25647	validation_1-logloss:0.27592
# [106]	validation_0-logloss:0.25635	validation_1-logloss:0.27589
# [107]	validation_0-logloss:0.25628	validation_1-logloss:0.27591
# [108]	validation_0-logloss:0.25606	validation_1-logloss:0.27585
# [109]	validation_0-logloss:0.25590	validation_1-logloss:0.27571
# [110]	validation_0-logloss:0.25586	validation_1-logloss:0.27562
# [111]	validation_0-logloss:0.25574	validation_1-logloss:0.27547
# [112]	validation_0-logloss:0.25551	validation_1-logloss:0.27554
# [113]	validation_0-logloss:0.25540	validation_1-logloss:0.27557
# [114]	validation_0-logloss:0.25491	validation_1-logloss:0.27558
# [115]	validation_0-logloss:0.25477	validation_1-logloss:0.27560
# [116]	validation_0-logloss:0.25469	validation_1-logloss:0.27555
# [117]	validation_0-logloss:0.25449	validation_1-logloss:0.27552
# [118]	validation_0-logloss:0.25426	validation_1-logloss:0.27558
# [119]	validation_0-logloss:0.25417	validation_1-logloss:0.27558
# [120]	validation_0-logloss:0.25405	validation_1-logloss:0.27547
# [121]	validation_0-logloss:0.25385	validation_1-logloss:0.27536
# [122]	validation_0-logloss:0.25374	validation_1-logloss:0.27534
# [123]	validation_0-logloss:0.25339	validation_1-logloss:0.27524
# [124]	validation_0-logloss:0.25333	validation_1-logloss:0.27527
# [125]	validation_0-logloss:0.25319	validation_1-logloss:0.27525
# [126]	validation_0-logloss:0.25311	validation_1-logloss:0.27521
# [127]	validation_0-logloss:0.25304	validation_1-logloss:0.27523
# [128]	validation_0-logloss:0.25268	validation_1-logloss:0.27514
# [129]	validation_0-logloss:0.25240	validation_1-logloss:0.27496
# [130]	validation_0-logloss:0.25231	validation_1-logloss:0.27490
# [131]	validation_0-logloss:0.25223	validation_1-logloss:0.27491
# [132]	validation_0-logloss:0.25208	validation_1-logloss:0.27484
# [133]	validation_0-logloss:0.25197	validation_1-logloss:0.27474
# [134]	validation_0-logloss:0.25191	validation_1-logloss:0.27472
# [135]	validation_0-logloss:0.25183	validation_1-logloss:0.27479
# [136]	validation_0-logloss:0.25174	validation_1-logloss:0.27481
# [137]	validation_0-logloss:0.25154	validation_1-logloss:0.27467
# [138]	validation_0-logloss:0.25147	validation_1-logloss:0.27460
# [139]	validation_0-logloss:0.25120	validation_1-logloss:0.27466
# [140]	validation_0-logloss:0.25091	validation_1-logloss:0.27462
# [141]	validation_0-logloss:0.25072	validation_1-logloss:0.27460
# [142]	validation_0-logloss:0.25060	validation_1-logloss:0.27459
# [143]	validation_0-logloss:0.25057	validation_1-logloss:0.27455
# [144]	validation_0-logloss:0.25052	validation_1-logloss:0.27452
# [145]	validation_0-logloss:0.25041	validation_1-logloss:0.27450
# [146]	validation_0-logloss:0.25015	validation_1-logloss:0.27457
# [147]	validation_0-logloss:0.25004	validation_1-logloss:0.27456
# [148]	validation_0-logloss:0.24964	validation_1-logloss:0.27462
# [149]	validation_0-logloss:0.24937	validation_1-logloss:0.27465
# [150]	validation_0-logloss:0.24932	validation_1-logloss:0.27457
# [151]	validation_0-logloss:0.24909	validation_1-logloss:0.27457
# [152]	validation_0-logloss:0.24899	validation_1-logloss:0.27445
# [153]	validation_0-logloss:0.24895	validation_1-logloss:0.27443
# [154]	validation_0-logloss:0.24878	validation_1-logloss:0.27433
# [155]	validation_0-logloss:0.24859	validation_1-logloss:0.27421
# [156]	validation_0-logloss:0.24842	validation_1-logloss:0.27422
# [157]	validation_0-logloss:0.24831	validation_1-logloss:0.27412
# [158]	validation_0-logloss:0.24824	validation_1-logloss:0.27423
# [159]	validation_0-logloss:0.24811	validation_1-logloss:0.27430
# [160]	validation_0-logloss:0.24800	validation_1-logloss:0.27425
# [161]	validation_0-logloss:0.24796	validation_1-logloss:0.27429
# [162]	validation_0-logloss:0.24763	validation_1-logloss:0.27429
# [163]	validation_0-logloss:0.24748	validation_1-logloss:0.27434
# [164]	validation_0-logloss:0.24735	validation_1-logloss:0.27443
# [165]	validation_0-logloss:0.24722	validation_1-logloss:0.27450
# [166]	validation_0-logloss:0.24715	validation_1-logloss:0.27453
# [167]	validation_0-logloss:0.24714	validation_1-logloss:0.27454
# [168]	validation_0-logloss:0.24702	validation_1-logloss:0.27453
# [169]	validation_0-logloss:0.24694	validation_1-logloss:0.27446
# [170]	validation_0-logloss:0.24684	validation_1-logloss:0.27439
# [171]	validation_0-logloss:0.24676	validation_1-logloss:0.27448
# [172]	validation_0-logloss:0.24666	validation_1-logloss:0.27444
# [173]	validation_0-logloss:0.24661	validation_1-logloss:0.27448
# [174]	validation_0-logloss:0.24653	validation_1-logloss:0.27454
# [175]	validation_0-logloss:0.24641	validation_1-logloss:0.27461
# [176]	validation_0-logloss:0.24632	validation_1-logloss:0.27458
# [177]	validation_0-logloss:0.24628	validation_1-logloss:0.27458
# [178]	validation_0-logloss:0.24619	validation_1-logloss:0.27455
# [179]	validation_0-logloss:0.24606	validation_1-logloss:0.27451
# [180]	validation_0-logloss:0.24601	validation_1-logloss:0.27448
# [181]	validation_0-logloss:0.24594	validation_1-logloss:0.27451
# [182]	validation_0-logloss:0.24544	validation_1-logloss:0.27471
# [183]	validation_0-logloss:0.24539	validation_1-logloss:0.27462
# [184]	validation_0-logloss:0.24533	validation_1-logloss:0.27457
# [185]	validation_0-logloss:0.24516	validation_1-logloss:0.27456
# [186]	validation_0-logloss:0.24509	validation_1-logloss:0.27450
# [187]	validation_0-logloss:0.24501	validation_1-logloss:0.27445
# [188]	validation_0-logloss:0.24482	validation_1-logloss:0.27448
# [189]	validation_0-logloss:0.24468	validation_1-logloss:0.27443
# [190]	validation_0-logloss:0.24466	validation_1-logloss:0.27441
# [191]	validation_0-logloss:0.24463	validation_1-logloss:0.27440
# [192]	validation_0-logloss:0.24459	validation_1-logloss:0.27438
# [193]	validation_0-logloss:0.24448	validation_1-logloss:0.27437
# [194]	validation_0-logloss:0.24444	validation_1-logloss:0.27434
# [195]	validation_0-logloss:0.24442	validation_1-logloss:0.27436
# [196]	validation_0-logloss:0.24427	validation_1-logloss:0.27432
# [197]	validation_0-logloss:0.24424	validation_1-logloss:0.27438
# [198]	validation_0-logloss:0.24422	validation_1-logloss:0.27443
# [199]	validation_0-logloss:0.24406	validation_1-logloss:0.27434
# [200]	validation_0-logloss:0.24403	validation_1-logloss:0.27433
# [201]	validation_0-logloss:0.24398	validation_1-logloss:0.27437
# [202]	validation_0-logloss:0.24389	validation_1-logloss:0.27424
# [203]	validation_0-logloss:0.24353	validation_1-logloss:0.27434
# [204]	validation_0-logloss:0.24351	validation_1-logloss:0.27440
# [205]	validation_0-logloss:0.24319	validation_1-logloss:0.27448
# [206]	validation_0-logloss:0.24313	validation_1-logloss:0.27452
# [207]	validation_0-logloss:0.24312	validation_1-logloss:0.27454
# [208]	validation_0-logloss:0.24302	validation_1-logloss:0.27458
# [209]	validation_0-logloss:0.24296	validation_1-logloss:0.27450
# [210]	validation_0-logloss:0.24294	validation_1-logloss:0.27450
# [211]	validation_0-logloss:0.24285	validation_1-logloss:0.27454
# [212]	validation_0-logloss:0.24278	validation_1-logloss:0.27457
# [213]	validation_0-logloss:0.24276	validation_1-logloss:0.27455
# [214]	validation_0-logloss:0.24259	validation_1-logloss:0.27456
# [215]	validation_0-logloss:0.24243	validation_1-logloss:0.27454
# [216]	validation_0-logloss:0.24223	validation_1-logloss:0.27468
# [217]	validation_0-logloss:0.24217	validation_1-logloss:0.27472
# [218]	validation_0-logloss:0.24205	validation_1-logloss:0.27476
# [219]	validation_0-logloss:0.24202	validation_1-logloss:0.27481
# [220]	validation_0-logloss:0.24200	validation_1-logloss:0.27482
# [221]	validation_0-logloss:0.24198	validation_1-logloss:0.27481
# [222]	validation_0-logloss:0.24146	validation_1-logloss:0.27489
# [223]	validation_0-logloss:0.24118	validation_1-logloss:0.27478
# [224]	validation_0-logloss:0.24097	validation_1-logloss:0.27483
# [225]	validation_0-logloss:0.24093	validation_1-logloss:0.27483
# [226]	validation_0-logloss:0.24089	validation_1-logloss:0.27488
# [227]	validation_0-logloss:0.24067	validation_1-logloss:0.27503
# [228]	validation_0-logloss:0.24047	validation_1-logloss:0.27507
# [229]	validation_0-logloss:0.24032	validation_1-logloss:0.27517
# [230]	validation_0-logloss:0.24022	validation_1-logloss:0.27511
# [231]	validation_0-logloss:0.24020	validation_1-logloss:0.27513
# [232]	validation_0-logloss:0.24002	validation_1-logloss:0.27506
# [233]	validation_0-logloss:0.23996	validation_1-logloss:0.27506
# [234]	validation_0-logloss:0.23978	validation_1-logloss:0.27526
# [235]	validation_0-logloss:0.23962	validation_1-logloss:0.27527
# [236]	validation_0-logloss:0.23946	validation_1-logloss:0.27521
# [237]	validation_0-logloss:0.23937	validation_1-logloss:0.27528
# [238]	validation_0-logloss:0.23927	validation_1-logloss:0.27529
# [239]	validation_0-logloss:0.23923	validation_1-logloss:0.27531
# [240]	validation_0-logloss:0.23920	validation_1-logloss:0.27532
# [241]	validation_0-logloss:0.23901	validation_1-logloss:0.27546
# [242]	validation_0-logloss:0.23892	validation_1-logloss:0.27541
# [243]	validation_0-logloss:0.23890	validation_1-logloss:0.27542
# [244]	validation_0-logloss:0.23880	validation_1-logloss:0.27534
# [245]	validation_0-logloss:0.23860	validation_1-logloss:0.27544
# [246]	validation_0-logloss:0.23855	validation_1-logloss:0.27549
# [247]	validation_0-logloss:0.23852	validation_1-logloss:0.27547
# [248]	validation_0-logloss:0.23826	validation_1-logloss:0.27565
# [249]	validation_0-logloss:0.23822	validation_1-logloss:0.27561
# [250]	validation_0-logloss:0.23815	validation_1-logloss:0.27556
# [251]	validation_0-logloss:0.23800	validation_1-logloss:0.27574
# [252]	validation_0-logloss:0.23787	validation_1-logloss:0.27579
# [253]	validation_0-logloss:0.23763	validation_1-logloss:0.27593
# [254]	validation_0-logloss:0.23759	validation_1-logloss:0.27596
# [255]	validation_0-logloss:0.23726	validation_1-logloss:0.27603
# [256]	validation_0-logloss:0.23702	validation_1-logloss:0.27587
# 오차 행렬
# [[5228  343]
#  [ 599 1157]]
# 정확도: 0.87143, 정밀도: 0.7713, 재현율: 0.6589,    F1: 0.7107, AUC:0.9284
